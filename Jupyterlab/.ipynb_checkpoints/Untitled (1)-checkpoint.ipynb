# %%
import pandas as pd

# %%
import sys
sys.path.insert(2,'X:\github\ThesisProject')

# %%
import functions

# %%
df = pd.read_json(r'C:\Thesis\Datasets\option_data-main\alphabet_2018.json.bz2', compression='bz2', orient='index')

# %%
S = 1073.654411  # underlying stock spot price 
K = 1000.0 # Strike price of option
t =  0.027397  # time to maturity 
r = 0.027397	 # risk free rate

call_price = 75.20

# %%
functions.implied_volatility(call_price, S, K, t, r)
# Out:
# 0.2549351818254647

# %%
df.iloc[1]
# Out:
# date                2018-01-02 00:00:00
# forward_price               1073.654411
# time_to_maturity                     10
# tau                            0.027397
# risk_free_rate                 0.015111
# is_call                               1
# strike_price                     1002.5
# option_price                      73.35
# Name: 1, dtype: object

# %%
df[(df['date']=='2018-01-02')&( df['is_call']==1)&(df['time_to_maturity']==10)]
# Out:
#           date  forward_price  time_to_maturity       tau  risk_free_rate  \
# 0   2018-01-02    1073.654411                10  0.027397        0.015111
# 1   2018-01-02    1073.654411                10  0.027397        0.015111
# 2   2018-01-02    1073.654411                10  0.027397        0.015111
# 3   2018-01-02    1073.654411                10  0.027397        0.015111
# 4   2018-01-02    1073.654411                10  0.027397        0.015111
# ..         ...            ...               ...       ...             ...
# 129 2018-01-02    1073.654411                10  0.027397        0.015111
# 130 2018-01-02    1073.654411                10  0.027397        0.015111
# 131 2018-01-02    1073.654411                10  0.027397        0.015111
# 132 2018-01-02    1073.654411                10  0.027397        0.015111
# 133 2018-01-02    1073.654411                10  0.027397        0.015111
#
#      is_call  strike_price  option_price
# ...

# %%
df.iloc[170]
# Out:
# date                2018-01-02 00:00:00
# forward_price               1073.654411
# time_to_maturity                     10
# tau                            0.027397
# risk_free_rate                 0.015111
# is_call                              -1
# strike_price                     1090.0
# option_price                      19.25
# Name: 170, dtype: object

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.to_excel('options_data.xlsx', index=False, engine='openpyxl')

# %%
unique_dates = df.index.get_level_values(0).unique()

# %%
unique_dates = df['date'].unique()

# %%
unique_dates=unique_dates.strftime('%Y/%m/%d')

# %%
print(unique_dates)
# Out:
# ['2018/01/02' '2018/01/03' '2018/01/04' '2018/01/05' '2018/01/08'
#  '2018/01/09' '2018/01/10' '2018/01/11' '2018/01/12' '2018/01/16'
#  '2018/01/17' '2018/01/18' '2018/01/19' '2018/01/22' '2018/01/23'
#  '2018/01/24' '2018/01/25' '2018/01/26' '2018/01/29' '2018/01/30'
#  '2018/01/31' '2018/02/01' '2018/02/02' '2018/02/05' '2018/02/06'
#  '2018/02/07' '2018/02/08' '2018/02/09' '2018/02/12' '2018/02/13'
#  '2018/02/14' '2018/02/15' '2018/02/16' '2018/02/20' '2018/02/21'
#  '2018/02/22' '2018/02/23' '2018/02/26' '2018/02/27' '2018/02/28'
#  '2018/03/01' '2018/03/02' '2018/03/05' '2018/03/06' '2018/03/07'
#  '2018/03/08' '2018/03/09' '2018/03/12' '2018/03/13' '2018/03/14'
#  '2018/03/15' '2018/03/16' '2018/03/19' '2018/03/20' '2018/03/21'
#  '2018/03/22' '2018/03/23' '2018/03/26' '2018/03/27' '2018/03/28'
#  '2018/03/29' '2018/04/02' '2018/04/03' '2018/04/04' '2018/04/05'
#  '2018/04/06' '2018/04/09' '2018/04/10' '2018/04/11' '2018/04/12'
# ...

# %%
df['time_to_maturity']
# Out:
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
#          ...
# 642635    536
# 642636    536
# 642637    536
# 642638    536
# 642639    536
# Name: time_to_maturity, Length: 642640, dtype: int64

# %%
changes = df['time_to_maturity'] != df['time_to_maturity'].shift()

# Filtering the DataFrame to keep only rows where changes occurred
result_df = df[changes]

# Display the result
print(result_df)
# Out:
#              date  forward_price  time_to_maturity       tau  risk_free_rate  \
# 0      2018-01-02    1073.654411                10  0.027397        0.015111
# 220    2018-01-02    1073.977497                17  0.046575        0.015349
# 461    2018-01-02    1074.310893                24  0.065753        0.015593
# 666    2018-01-02    1074.654433                31  0.084932        0.015836
# 804    2018-01-02    1075.008128                38  0.104110        0.016080
# ...           ...            ...               ...       ...             ...
# 641451 2018-12-31    1048.474627                46  0.126027        0.026643
# 641682 2018-12-31    1050.725879                74  0.202740        0.027141
# 641939 2018-12-31    1058.471641               172  0.471233        0.027263
# 642158 2018-12-31    1075.028962               382  1.046575        0.027107
# 642440 2018-12-31    1086.972254               536  1.468493        0.026842
#
#         is_call  strike_price  option_price
# ...

# %%
 df['time_to_maturity'].unique()
# Out:
# array([ 10,  17,  24,  31,  38,  45,  73, 108, 164, 262, 381, 535,   9,
#         16,  23,  30,  37,  44,  72, 107, 163, 261, 380, 534,   8,  15,
#         22,  29,  36,  43,  50,  71, 106, 162, 260, 379, 533,   7,  14,
#         21,  28,  35,  42,  49,  70, 105, 161, 259, 378, 532,  11,  18,
#         25,  32,  39,  46,  67, 102, 158, 256, 375, 529,  66, 101, 157,
#        255, 374, 528,  65, 100, 156, 254, 373, 527,  64,  99, 155, 253,
#        372, 526,  63,  98, 154, 252, 371, 525,  59,  94, 150, 248, 367,
#        521,  58,  93, 121, 149, 247, 366, 520, 730,  57,  92, 120, 148,
#        246, 365, 519, 729,  56,  91, 119, 147, 245, 364, 518, 728,  53,
#         88, 116, 144, 242, 361, 515, 725,  52,  87, 115, 143, 241, 360,
#        514, 724,  51,  86, 114, 142, 240, 359, 513, 723,  85, 113, 141,
#        239, 358, 512, 722,  84, 112, 140, 238, 357, 511, 721,  81, 109,
#        137, 235, 354, 508, 718,  80, 136, 234, 353, 507, 717,  79, 135,
# ...
